# %%
import sys
import os
import yaml

# Add src directory to sys.path for imports
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..", "src")))

# Now you can import your class
from simulationkrig import SimulationLoader, SimulationKrig

# %%
# Load the config from the configs directory
config_path = os.path.abspath(os.path.join(os.getcwd(), "..", "configs/simulationkrig.yaml"))

loader = SimulationLoader(config_path)

# Get discharge data for a specific date
year, month, day = 1982, 12, 10
data = loader.get_streamflow(year, month, day)
# Out:
# Summary Statistics for 1982-12-10:
#   - Number of simulations: 531
#   - Min: -0.02 mm/day
#   - Max: 18.56 mm/day
#   - Mean: 1.41 mm/day
#   - Std Dev: 1.88 mm/day
#   - WARNING: 6 negative values found:
#     - 05057200: (47.2292, -98.1248) → -0.01
#     - 06470800: (46.2252, -98.0718) → -0.01
#     - 06847900: (39.7698, -100.1008) → -0.00
#     - 07299670: (34.3545, -99.7404) → -0.01
#     - 08164300: (29.4669, -96.8128) → -0.02
#     - 08189500: (28.2919, -97.2792) → -0.00

# %%
# Initialize kriging analysis
krig = SimulationKrig(data, config_path, year, month, day)

# %%
# Compute kriging first
krig.compute_kriging()
# Out:
# Computing Kriging using spherical variogram model...

# %%
# Plot the variogram
krig.plot_variogram()

# %%
# Generate the kriging interpolation map
krig.map_krig_interpolation()

# %%
# Generate the kriging error variance map
krig.map_krig_error_variance()
