# %%
import sys
import os
import yaml

# Add src directory to sys.path for imports
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..", "src")))

# Now you can import your class
from camelskrig import CamelsLoader, CamelsKrig

# %%
# Load the config from the configs directory
config_path = os.path.abspath(os.path.join(os.getcwd(), "..", "configs/camelskrig.yaml"))

loader = CamelsLoader(config_path)

# Get discharge data for a specific date
year, month, day = 1982, 12, 10
data = loader.get_streamflow(year, month, day)
# Out:
# Summary Statistics for 1982-12-10:
#   - Number of observations: 614
#   - Min streamflow: -172.97 mm/day
#   - Max streamflow: 16.50 mm/day
#   - Mean streamflow: 0.82 mm/day
#   - Std deviation: 7.44 mm/day
#   - WARNING: 9 negative values detected!
#   - Locations of negative values (gauge_id, lon, lat, streamflow):
#     - Gauge 02310947: (-82.0559, 28.3119) -> -4.20 mm/day
#     - Gauge 03187500: (-80.5265, 38.2954) -> -11.75 mm/day
#     - Gauge 03450000: (-82.4053, 35.6531) -> -172.97 mm/day
#     - Gauge 06043500: (-111.2705, 45.4974) -> -1.15 mm/day
#     - Gauge 08155200: (-97.9256, 30.2963) -> -10.12 mm/day
#     - Gauge 09505200: (-111.6721, 34.6747) -> -8.50 mm/day
#     - Gauge 10258000: (-116.5592, 33.8050) -> -32.28 mm/day
#     - Gauge 12043000: (-124.3930, 47.9601) -> -7.02 mm/day
#     - Gauge 13310700: (-115.7250, 44.9869) -> -2.86 mm/day

# %%
# Initialize kriging analysis
krig = CamelsKrig(data, config_path, year, month, day)

# %%
# Compute kriging first
krig.compute_kriging()
# Out:
# Computing Kriging using spherical variogram model...

# %%
# Plot the variogram
krig.plot_variogram()

# %%
# Generate the kriging interpolation map
krig.map_krig_interpolation()

# %%
# Generate the kriging error variance map
krig.map_krig_error_variance()
